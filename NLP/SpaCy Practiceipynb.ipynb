# %%
import spacy 
nlp = spacy.load('en_core_web_sm')

# Create an nlp object
doc = nlp("He went to play basketball")
 
# Iterate over the tokens
for token in doc:
    # Print the token and its part-of-speech tag
    print(token.text, "-->", token.pos_)
# Out:
# He --> PRON
# went --> VERB
# to --> PART
# play --> VERB
# basketball --> NOUN

# %%
spacy.explain("PART")
# Out:
# 'particle'

# %%
# dependency parsing
for token in doc:
    print(token.text, "-->", token.dep_)
# Out:
# He --> nsubj
# went --> ROOT
# to --> aux
# play --> advcl
# basketball --> dobj

# %%
spacy.explain("nsubj"), spacy.explain("ROOT"), spacy.explain("aux"), spacy.explain("advcl"), spacy.explain("dobj")
# Out:
# ('nominal subject',
#  None,
#  'auxiliary',
#  'adverbial clause modifier',
#  'direct object')

# %%
doc = nlp("Indians spent over $71 billion on clothes in 2018")
 
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Indians NORP
# $71 billion MONEY
# 2018 DATE

# %%
spacy.explain("NORP")
# Out:
# 'Nationalities or religious or political groups'

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Import spaCy Matcher
from spacy.matcher import Matcher

# Initialize the matcher with the spaCy vocabulary
matcher = Matcher(nlp.vocab)

doc = nlp("Some people start their day with lemon water")

# Define rule
pattern = [{'TEXT': 'lemon'}, {'TEXT': 'water'}]

# Add rule
matcher.add('rule_1', None, pattern)

# %%
matches = matcher(doc) matches
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-420524c2269a> in <module>()
# ----> 1 matches = matcher(doc). matches
#
# AttributeError: 'list' object has no attribute 'matches'

# %%
# Extract matched text
for match_id, start, end in matches:
    # Get the matched span
    matched_span = doc[start:end]
    print(matched_span.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-04e4ee143171> in <module>()
#       1 # Extract matched text
# ----> 2 for match_id, start, end in matches:
#       3     # Get the matched span
#       4     matched_span = doc[start:end]
#       5     print(matched_span.text)
#
# NameError: name 'matches' is not defined

# %%
doc1 = nlp("You read this book")
doc2 = nlp("I will book my ticket")

pattern = [{'TEXT': 'book', 'POS': 'NOUN'}]

# Initialize the matcher with the shared vocab
matcher = Matcher(nlp.vocab)
matcher.add('rule_2', None, pattern)

# %%
matches = matcher(doc1) 
matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9e9c067595b0> in <module>()
# ----> 1 matches = matcher(doc1)
#       2 matches
#
# NameError: name 'doc1' is not defined

# %%
matches = matcher(doc2) 
matches
