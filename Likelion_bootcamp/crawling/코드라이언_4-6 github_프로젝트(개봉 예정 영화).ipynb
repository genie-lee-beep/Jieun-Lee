# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://movie.naver.com/movie/running/premovie.nhn'

page = urlopen(url)
soup = BeautifulSoup(page, "lxml")

# %%
title = soup.find("div", class_="article").find_all("dt",class_="tit")
title
# Out:
# [<dt class="tit">
#  <span class="ico_rating_18">청소년 관람불가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=34309">2046</a>
#  <!-- N=a:sol.title,r:1,i:34309 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_18">청소년 관람불가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=204624">킬러의 보디가드 2</a>
#  <!-- N=a:sol.title,r:2,i:204624 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=194205">발신제한</a>
#  <!-- N=a:sol.title,r:3,i:194205 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=199068">메이드 인 루프탑</a>
#  <!-- N=a:sol.title,r:4,i:199068 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=200353">데이팅 앰버</a>
#  <!-- N=a:sol.title,r:5,i:200353 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_all">전체 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=185148">흩어진 밤</a>
#  <!-- N=a:sol.title,r:6,i:185148 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=203225">뱅퀴시</a>
#  <!-- N=a:sol.title,r:7,i:203225 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_all">전체 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=204174">식물카페, 온정</a>
#  <!-- N=a:sol.title,r:8,i:204174 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=203668">신해석 삼국지</a>
#  <!-- N=a:sol.title,r:9,i:203668 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=186410">크레센도</a>
#  <!-- N=a:sol.title,r:10,i:186410 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_all">전체 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=119126">북샵</a>
#  <!-- N=a:sol.title,r:11,i:119126 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=167652">진삼국무쌍</a>
#  <!-- N=a:sol.title,r:12,i:167652 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_all">전체 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=194715">아사다 가족</a>
#  <!-- N=a:sol.title,r:13,i:194715 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=189120">미드나이트</a>
#  <!-- N=a:sol.title,r:14,i:189120 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=188195">우리는 매일매일</a>
#  <!-- N=a:sol.title,r:15,i:188195 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=205629">괴기맨숀</a>
#  <!-- N=a:sol.title,r:16,i:205629 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=193536">다크 앤드 위키드</a>
#  <!-- N=a:sol.title,r:17,i:193536 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=198236">더 배니싱</a>
#  <!-- N=a:sol.title,r:18,i:198236 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=144254">레일로드 워</a>
#  <!-- N=a:sol.title,r:19,i:144254 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=198555">블라이스 스피릿</a>
#  <!-- N=a:sol.title,r:20,i:198555 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=193327">빛나는 순간</a>
#  <!-- N=a:sol.title,r:21,i:193327 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=203721">열아홉</a>
#  <!-- N=a:sol.title,r:22,i:203721 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=191926">웬디</a>
#  <!-- N=a:sol.title,r:23,i:191926 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=18878">이보다 더 좋을 순 없다</a>
#  <!-- N=a:sol.title,r:24,i:18878 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=191631">인 더 하이츠</a>
#  <!-- N=a:sol.title,r:25,i:191631 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=194663">저승보다 낯선</a>
#  <!-- N=a:sol.title,r:26,i:194663 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=194886">좀비크러쉬: 헤이리</a>
#  <!-- N=a:sol.title,r:27,i:194886 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=204782">체르노빌 1986</a>
#  <!-- N=a:sol.title,r:28,i:204782 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=199860">기적</a>
#  <!-- N=a:sol.title,r:29,i:199860 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=191929">암살자들</a>
#  <!-- N=a:sol.title,r:30,i:191929 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=171476">켈리 갱</a>
#  <!-- N=a:sol.title,r:31,i:171476 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_all">전체 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=197443">매직아치</a>
#  <!-- N=a:sol.title,r:32,i:197443 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_18">청소년 관람불가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=201786">시카다 3301</a>
#  <!-- N=a:sol.title,r:33,i:201786 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=205303">아이윌 송</a>
#  <!-- N=a:sol.title,r:34,i:205303 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=184318">블랙 위도우</a>
#  <!-- N=a:sol.title,r:35,i:184318 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=177504">미션 임파서블: 루벤</a>
#  <!-- N=a:sol.title,r:36,i:177504 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=193525">트립 투 그리스</a>
#  <!-- N=a:sol.title,r:37,i:193525 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=200896">꽃다발 같은 사랑을 했다</a>
#  <!-- N=a:sol.title,r:38,i:200896 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_18">청소년 관람불가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=193971">더 퍼지: 포에버</a>
#  <!-- N=a:sol.title,r:39,i:193971 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=168074">오필리아</a>
#  <!-- N=a:sol.title,r:40,i:168074 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=191548">이스케이프 룸 2: 노 웨이 아웃</a>
#  <!-- N=a:sol.title,r:41,i:191548 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=205285">와인 패밀리</a>
#  <!-- N=a:sol.title,r:42,i:205285 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_18">청소년 관람불가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=23138">죽어도 좋은 경험</a>
#  <!-- N=a:sol.title,r:43,i:23138 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=205968">극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들</a>
#  <!-- N=a:sol.title,r:44,i:205968 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=198327">나는 나대로 혼자서 간다</a>
#  <!-- N=a:sol.title,r:45,i:198327 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=205614">나만 보이니</a>
#  <!-- N=a:sol.title,r:46,i:205614 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=191443">더 나이트</a>
#  <!-- N=a:sol.title,r:47,i:191443 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=204496">랑종</a>
#  <!-- N=a:sol.title,r:48,i:204496 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=203678">스페이스 잼: 새로운 시대</a>
#  <!-- N=a:sol.title,r:49,i:203678 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=201783">액션히어로</a>
#  <!-- N=a:sol.title,r:50,i:201783 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=66274">옥스포드 살인사건</a>
#  <!-- N=a:sol.title,r:51,i:66274 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_12">12세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=191927">워스</a>
#  <!-- N=a:sol.title,r:52,i:191927 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=201272">은혼 더 파이널</a>
#  <!-- N=a:sol.title,r:53,i:201272 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=203465">이번엔 잘 되겠지</a>
#  <!-- N=a:sol.title,r:54,i:203465 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=179406">정글 크루즈</a>
#  <!-- N=a:sol.title,r:55,i:179406 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=186889">페이블</a>
#  <!-- N=a:sol.title,r:56,i:186889 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=205982">피어 오브 레인</a>
#  <!-- N=a:sol.title,r:57,i:205982 -->
#  </dt>,
#  <dt class="tit">
#  <span class="ico_rating_15">15세 관람가</span>
#  <a href="/movie/bi/mi/basic.nhn?code=198259">호스트: 접속금지</a>
#  <!-- N=a:sol.title,r:58,i:198259 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=187323">베놈 2: 렛 데어 비 카니지</a>
#  <!-- N=a:sol.title,r:59,i:187323 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=99702">007 노 타임 투 다이</a>
#  <!-- N=a:sol.title,r:60,i:99702 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=180429">웨스트 사이드 스토리</a>
#  <!-- N=a:sol.title,r:61,i:180429 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=190695">모비우스</a>
#  <!-- N=a:sol.title,r:62,i:190695 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=191646">쥬라기 월드: 도미니언</a>
#  <!-- N=a:sol.title,r:63,i:191646 -->
#  </dt>,
#  <dt class="tit">
#  <a href="/movie/bi/mi/basic.nhn?code=191634">미니언즈2</a>
#  <!-- N=a:sol.title,r:64,i:191634 -->
#  </dt>]

# %%
movie_title = []
for one in title:
  one_movie = one.find("a").text
  movie_title.append(one_movie)
movie_title
# Out:
# ['2046',
#  '킬러의 보디가드 2',
#  '발신제한',
#  '메이드 인 루프탑',
#  '데이팅 앰버',
#  '흩어진 밤',
#  '뱅퀴시',
#  '식물카페, 온정',
#  '신해석 삼국지',
#  '크레센도',
#  '북샵',
#  '진삼국무쌍',
#  '아사다 가족',
#  '미드나이트',
#  '우리는 매일매일',
#  '괴기맨숀',
#  '다크 앤드 위키드',
#  '더 배니싱',
#  '레일로드 워',
#  '블라이스 스피릿',
#  '빛나는 순간',
#  '열아홉',
#  '웬디',
#  '이보다 더 좋을 순 없다',
#  '인 더 하이츠',
#  '저승보다 낯선',
#  '좀비크러쉬: 헤이리',
#  '체르노빌 1986',
#  '기적',
#  '암살자들',
#  '켈리 갱',
#  '매직아치',
#  '시카다 3301',
#  '아이윌 송',
#  '블랙 위도우',
#  '미션 임파서블: 루벤',
#  '트립 투 그리스',
#  '꽃다발 같은 사랑을 했다',
#  '더 퍼지: 포에버',
#  '오필리아',
#  '이스케이프 룸 2: 노 웨이 아웃',
#  '와인 패밀리',
#  '죽어도 좋은 경험',
#  '극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들',
#  '나는 나대로 혼자서 간다',
#  '나만 보이니',
#  '더 나이트',
#  '랑종',
#  '스페이스 잼: 새로운 시대',
#  '액션히어로',
#  '옥스포드 살인사건',
#  '워스',
#  '은혼 더 파이널',
#  '이번엔 잘 되겠지',
#  '정글 크루즈',
#  '페이블',
#  '피어 오브 레인',
#  '호스트: 접속금지',
#  '베놈 2: 렛 데어 비 카니지',
#  '007 노 타임 투 다이',
#  '웨스트 사이드 스토리',
#  '모비우스',
#  '쥬라기 월드: 도미니언',
#  '미니언즈2']
