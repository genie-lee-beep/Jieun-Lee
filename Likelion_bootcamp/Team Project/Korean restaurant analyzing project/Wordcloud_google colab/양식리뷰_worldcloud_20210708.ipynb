# %%
### 나눔 고딕 설치
# !apt-get update -qq # 설치를 업데이트
# !apt-get install fonts-nanum* -qq # 설치한다. fonts-nanum*
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160815 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm # 폰트 관련 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic Eco

# %% [markdown]
# ## 런타임 다시시작

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
## 음수 표시되도록 설정
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumGothic Eco

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 157kB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/98/88/f817ef1af6f794e8f11313dcd1549de833f4599abcec82746ab5ed086686/JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 43.6MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.9MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, beautifulsoup4, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma ### 꼬꼬마
from konlpy.tag import Hannanum ### 한나눔

# %%
### wordcloud와 이미지 표시
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
### 데이터 읽기
### 코랩 파일에 다시 넣기 , 런타임 끝나면 자동 삭제됨
doc_ko = open("yanggsik_review.txt").read()
doc_ko[0:3000]
# Out:
# '이날 입은 옷도 그르쿠.. 식사하러 가서 전시를 보고 온 것 같은 느낌! 성수동 끝자락 찾아가기 힘든 골목에 위치하고 있고, 인테리어도 어두워서 눈에 잘 띄지는 않지만 예약이 힘든 이유가 있었다. 생면파스타는 처음이였는데 정말, 표현을 하기가 힘들다고 할까 너~무 부드러워서 그냥 입에 다들어감. 나는 이 식감이 맘에 들었는데 호불호는 갈릴수도 있겠다. 불만이라고 하면 함냐함냐함에 끝나는 양... 인당 2접시는 비울수 있을 것 같은. 메뉴들도 독특하고 녹진한 맛이 매우 마음에 들었던 곳 :) 만드는 것부터 음식을 내놓는 일련의 작업이 뭔가 전시를 보는 것 같기도 하고, 불편한듯 아늑한 분위기가 집에 가기 약간 아쉬웠다. 언젠가 예약이 쉬워지면 다시 가고싶은 곳.\t좋아요\t"전에 포스팅을 요즘들어 너무 생각나서 다시 업뎃해서 올리기로 했어요!\n요즘은 아예 수강신청이나 티켓팅보다 어렵다는 바위파스타바! 비록 갖다오자마자 예약제가 더 치열해지고 재방문 고객 위주로 바뀌었지만 9월에 방문했는데 불구하고 10월에 아쉽게도 나에게 아무 없어서 조금 아쉬었다 댓글로 11월에 결국 문의했는데 10월 손님부터 선착순으로 진행하신다해서 시기도 놓쳐서 슬픔가득\n\n하지만 치열한 만큼 이만한 가성비에 한국에 이런 맛인 파스타는 없다는거! 직접 눈 앞에서 생면을 뽑아주고 친절히 파스타 설명도 해주셨고 맛은 말잇못 면도 되게 얇은 편인데 식감이 풍부했고 밀가루의 거부감도 1도 없다\n아티초크와 민트 피스타치오 페스토 딸리올리니를 추천 받았을때 처음에는 조금 걱정이 되었다. 아무리 페스토와 피스타치오와 아티초크를 좋아하다지만 개인적으로 민트맛 극불호인데 무서웠다. 하지만 전혀 강하지 않고 오묘한 조합이 너무 잘 어우러져서 놀랐고 몇달이 지난 지금까지도 생각나는 맛이다. 어딜가서 먹을 수 없은 맛이긴 하니까\n\n우니와 오징어 먹물파스타 우니는 사랑이니까이미 우니를 잘게 썰어서 올려주신거라 그냥 올려진 사진들에 비해 덜 이쁘지만 맛은 극품이니 뭐어때\u200d♀️ 파스타 자체가 양이 많지 않은데 우니 듬북이라서 우니의 진한 맛이 제대로 느껴지고 비린내 나는 음식을 잘 못 먹는 분이랑 갔는데 전혀 비린맛이 없다고 칭찬했다\n\n아쉽게도 윈터 트러플은 없어서 썸머 트러플를 시켰지만 한국에서 먹어본 트러플 파스타 중에 가장 조화롭고 진했다. 사실 이태리에서 먹었던 트러플 파스타를 찾으러 다녔지만 그래도 바위파스타바가 제일 근접한거 같아서 행복했다 아쉬운 점이 있다면 위에 올려진 트러플이 입안에서 날렸다는 점 (트러플 맛 가쓰오부시)\n\n부러따랑 디저트인 파나코타는 완벽했다 하나하나 다 신경 쓰시는게 보이고 정말 파스타에 진심이신거 같아서 제대로 만족했다."\t.\t"이런집이 많아져야 합니다!\n정말 맛에 집중하고 또 집중한맛!!!\n꼭 가야만하는 집입니다 !!"\n맛있음 시간은 15분쯤 걸림\t"사당의 대표 맛집!\n\n프랜차이즈 식당들과 술집들이 가득한 사당역 인근에서 훌륭한 피자로 존재감을 보이고 있는 작은피자집입니다.\n\n이름처럼 공간은 좀 협소해서 대기도 곧잘 있는 피자집인데, 피자는 진짜 장난없습니다.\n일단 토핑들이 정말 풍성하게, 그득그득 올라가 있고 또 특이하게 딸기잼도 같이 주시는데, 은근 조화가 좋습니다.\n저는 주로 반반을 주문해서 하나는 트리플치즈 고정에 나머지 하나는 페페로니, 하와이안, 베이컨체다치즈 등을 먹어봤는데 모두 아쉬움 없이 만족스러웠어요! 그 날 그 날 땡기는 걸 드시면 될 듯한데 보통 페퍼로니와 트리플치즈를 많이 드시는 것 같아요.\n피자 외 메뉴로는 리코타 치즈 샐러드 뿐인데, 요것도 양과 맛 모두 만족스럽게 먹었네요.\n\n사실 장소가 협소하다보니 포장으로도 자주 먹긴 했는데, 그래도 매장에서 먹는 게 훨씬 맛있습니다.\n혹시 피자가 땡기신다면! 후회 없는 선택지가 될 거라 믿어 의심치 않습니다"\t"평범하면서도 뭔가 특별한 피자를 맛보고 싶다면\n작은피자집을 강추한다!\n\n사당역 근처 번화가에 숨어있는 작은피자집은 2시부터\n오픈인데, 애매한 오픈시간에도 불구하고 세 팀 모두 오픈을 기다리고\n있었다.\n\n페퍼로니, 트리플 치즈 반반은 식당 내에서, 불고기와 컴비네이션\n반반은 집에가져와서 맛보았다.\n만약 기본에 충실한 맛을 보고싶다면 전자를, 달콤하면서\n끝'

# %%
# OKT 클래스를 이용한 명사확인 Okt (11초 : 4286), Kkma (37초 : 5572)
from konlpy.tag import Okt ### Okt를 활용하여 명사를 가져옴
t = Okt()

doc_nouns = t.nouns(doc_ko)
print( len( doc_nouns ) )
# Out:
# 53398

# %%
# nltk.Text()를 이용하여 nltk가 가지는 많은 기능을 사용 가능해짐.
ko = nltk.Text(doc_nouns, name="양식리뷰") # nltk는 영어 자연어 처리, 띄어쓰기 단위를 token이라고 함 
print(type(ko))
print(len(ko.tokens))   #그냥 해봄
# Out:
# <class 'nltk.text.Text'>
# 53398

# %%
### 단어들의 사용 횟수 확인 - 빈도 분석
type( ko.vocab() ), ko.vocab().most_common(50)
# Out:
# (nltk.probability.FreqDist,
#  [('맛', 1079),
#   ('파스타', 664),
#   ('것', 589),
#   ('피자', 503),
#   ('메뉴', 489),
#   ('소스', 414),
#   ('곳', 408),
#   ('치즈', 400),
#   ('방문', 376),
#   ('더', 369),
#   ('수', 363),
#   ('느낌', 305),
#   ('버거', 298),
#   ('정말', 294),
#   ('생각', 284),
#   ('때', 284),
#   ('음식', 282),
#   ('이', 279),
#   ('주문', 277),
#   ('향', 265),
#   ('좀', 254),
#   ('정도', 252),
#   ('분위기', 251),
#   ('스테이크', 246),
#   ('샐러드', 243),
#   ('와인', 221),
#   ('가격', 220),
#   ('추천', 212),
#   ('집', 208),
#   ('요리', 206),
#   ('하나', 200),
#   ('그', 199),
#   ('안', 199),
#   ('빵', 191),
#   ('내', 169),
#   ('식당', 160),
#   ('나', 158),
#   ('여기', 158),
#   ('진짜', 157),
#   ('다른', 157),
#   ('크림', 157),
#   ('고기', 157),
#   ('리뷰', 154),
#   ('아주', 151),
#   ('처음', 147),
#   ('듯', 145),
#   ('조금', 142),
#   ('예약', 136),
#   ('또', 133),
#   ('양', 132)])

# %%
### 한글에서는 따로 불용어 사전 라이브러리 없어, 따로 만들거나 또는 파일로 부터 불러올 수 있다.
stop_words = ['여기', '그', '좀', '내','고기','갈비','방문','좀'
'하나', '조금', '식사', '다음', '말','재','김밥','테이블',
'점', '또', '음식', '때', '정도','것','곳','수','듯','또','조금','예약','처음','다른','나','그','집','하나',
'다른', '생각', '이', '안', '진짜','냉면','정말','메뉴']
new_ko = [ ]   #여기서 부터가 한글의 경우에 추가되는 부분
for one_word in ko:
  if one_word not in stop_words:  # 만약 one_word가 stop_word에 없으면 new_ko에 더하겠다. 
   new_ko.append(one_word)

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
new_ro2 = nltk.Text(new_ko, name="싸울아비 룬")
plt.figure(figsize=(20,16))
new_ro2.plot(50)

# %%
# Generate a word cloud image
mask = np.array(Image.open("steak.jpg"))




# hansik_mask = np.array(Image.open("ddokbargi.jpg"))

# %%
data = new_ro2.vocab().most_common(1000)

# %%
## 워드 클라우드 표현을 위한 데이터 생성
## 약간의 시간이 필요.
wc = WordCloud(background_color='white', 
max_words=200,
mask=mask,
contour_width=5, #외곽선
# contour_color="steelblue",  # 색
font_path=path).generate_from_frequencies(dict(data))

image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[5,5])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")



# store to file
plt.savefig("img/spa_wine.png", format="png")
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-833438a48786> in <module>()
#      16
#      17 # store to file
# ---> 18 plt.savefig("img/spa_wine.png", format="png")
#      19 #plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/spa_wine.png'

# %%
# store to file
plt.savefig("img/spa_wine.png", format="png")
#plt.show()



# plt.figure(figsize=(12,8))
# plt.imshow(wc)
# plt.axis("off")
# plt.show()
