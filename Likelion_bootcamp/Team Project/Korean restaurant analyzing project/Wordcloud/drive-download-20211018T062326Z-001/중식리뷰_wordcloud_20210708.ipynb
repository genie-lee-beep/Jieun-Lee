# %%
### 나눔 고딕 설치
# !apt-get update -qq # 설치를 업데이트
# !apt-get install fonts-nanum* -qq # 설치한다. fonts-nanum*
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160815 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm # 폰트 관련 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic Eco

# %% [markdown]
# ## 런타임 다시시작

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
## 음수 표시되도록 설정
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumGothic Eco

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.8MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 10.2MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/98/88/f817ef1af6f794e8f11313dcd1549de833f4599abcec82746ab5ed086686/JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 36.8MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Installing collected packages: colorama, beautifulsoup4, JPype1, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma ### 꼬꼬마
from konlpy.tag import Hannanum ### 한나눔

# %%
### wordcloud와 이미지 표시
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
### 데이터 읽기
### 코랩 파일에 다시 넣기 , 런타임 끝나면 자동 삭제됨
doc_ko = open("jungsik_review.txt").read()
doc_ko[0:3000]
# Out:
# '"[★★★★]\n\n생일 당일에 방문한 쥬에\n평소 제일 좋아하는 음식이 딤섬 인지라\n고르고 고르다 쥬에로 예약\n\n전복소매\n바닷가재 춘권\n새우창펀\n바삭한 돼지고기 바베큐\n상하이탕면\n\n둘이서 이렇게 5개를 시켰다\n중식은 메뉴 가짓수를 오바해서 시키는 편이라\n더 시키고 싶었지만\n\n새우창펀은 그동안 먹었던 창펀과 다르게\n안에 크리스피한 식감은 없었지만\n부드러운 식감에 적절한 소스간으로 맛있었다\n전복소매도 맛있었지만 다음 방문에는 다른 딤섬 메뉴를 먹어보는 걸로\n바닷가재 춘권은 트러플 향이 진하게 난다.\n먹을 때는 맛있게 먹긴 했지만 다른 메뉴를 더 맛있게 먹었었는데 집에 돌아오니 이 메뉴가 제일 생각 났다.\n트러플향이 진해서 그럴지도 (트러플 싫어하면 비추)\n바삭한 돼지 바베큐는 무조건 시키길..\n겨자소스랑 같이 나오는데 식감과 돼지고기 맛이 극대화\n이건 다시 와도 또 시킬 예정\n\n그리고 생일이라고 창가자리 , 장수의 의미라는 복숭아 후식까지 완벽한 생일상 난 cj입맛인 것 같다ㅋ"\t"쥬 에의 맛은 훌륭했으나 음식 템포는\n에 (애)간장을 태우기에 충분했다."\t"기대를 많이 해서일까요 처음 가본 쥬에는 그렇게 나쁘지 않았지만 그렇다고 추천할만한 맛은 아니었습니다.\n\n나름 구성이 괜찮아 보이는 후작 코스를 주문했습니다.\n\n웰컴 푸드와 바베큐, 샥스핀까지는 만족스러웠는데 딤섬이 좀 많이 아쉽네요.\n\n트러플, 캐비어, 전복 좋은 재료는 많이 쓰기는 했는데 재료의 맛을 제대로 못 살린 것 같아요. 제가 홍콩에 살았어서 딤섬 기준이 좀 높은 듯 하네요. ^^\n\n북경오리는 최근에 방문한 팔☆드신이 더 맛있었던 것 같습니다.\n\n다행히 백화전복은 맛있게 먹었네요.\n\n흑초탕수육은.대표 메뉴이고 리뷰도 좋아서 기대를 많이 했는데 실망스러웠습니다. 소스가 너무 진해서 티만 계속 마셨네요.\n\n마무리로 나온 차슈 볶음밥과 가지볶음 그리고 리찌 아이스크림은 다행히도 맛있게 먹었습니다 :)\n\n생각해보니 정말 코스가 업다운이 많았었네요. 집에 오면서 와이프와 내린 결론은 나쁘진 않지만 다시 가고 싶지 않다 였습니다.\n\n다음주에 팔☆드신 다시 예약했습니다. :)\n\n뭉뭉"\t"CJ에서 운영하는 중식당 미슐랭 쥬에\n이가격에 어울리는 맛과 퀄리티일까 싶긴합니다\n차라리 단품으로 드심이..."\t"드시계 일지#15-1. 섬세한 인테리어와 상반되는 아쉬운 서빙 순서\n\n갤러리같은 외관부터 섬세하게 배치되어 있는 그림과 조각상은 쥬에를 방문하는 순간부터 엄청난 기대를 갖게한다.\n넓은 통창에 햇볕도 잘 들고, 한쪽에서 차를 끓이는 모습을 보는 것도 쏠쏠한 재미인 곳.\n딤섬 3종, 흑초탕수육, 게살두부, 관자볶음밥, 송이버섯볶음을 주문하고 차로는 청차(무이기란)를 주문.\n\n1. 끝내주는 딤섬 ASMR 모음\n딤섬으로는 새우창펀, 송로버섯바다가재 춘권, 전복소매 세 종류를 주문. 결론적으로 세 개 모두 맛있다!\n이날 조화롭게 시킨 덕에 아주 다양한 식감으로 즐길 수 있었는데, 새우창펀은 야들한 식감으로 면치기 때보다 더 찰진 ‘호록호로록’ 소리를 내며 먹을 수 있다.\n부드러운 피 안에는 아주 탱글한 새우살이 있어 입술과 입 속 모두가 맛있는 딤섬!\n반면 바닷가재춘권은 한 입 먹는 순간 ‘바사삭’이 아닌 ‘파사사삭’ 씹힌다.\n안의 내용물은 사실 새우창펀만큼 인상깊진 않았지만 이 소리 덕분에 귀가 맛있어서 자꾸만 먹고싶어진다.\n마지막 전복소매는 안이 아주 꽉 차서는 부드러우면서도 적당한 쫄깃함을 한가득 선사한다. 부드러우면서도 탱글한 치감이 즐거웠던 딤섬.\n\n2. 강렬함 그 뒤 맛의 정적\n차도, 딤섬도 너무 만족스러워서 ‘맛있다, 맛있다’를 연발하다가 메인 요리가 나오면서 비극이 시작되었다.\n우리는 부드럽고 따뜻한 게살두부로 속을 달래고, 강렬한 흑초탕수육과 송이버섯볶음을 번갈아 먹다가 마무리로 관자볶음밥을 먹자는, 아주 치밀한(?) 미식 밸런스를 고려해 메인요리를 주문했다.\n그런데 첫 서빙으로 흑초탕수육이 단독으로 나왔고, 그 이후 요리들은 상당한 텀을 두고 나왔다.\n결국 흑초탕수육을 제일 먼저 먹었는데, 이름처럼 강렬한 흑초의 맛과 진한 지방의 맛때문에 이후 나온 요리들의 맛을 거의 느낄 수가 없었다.\n본연 재료의 맛에 가까운 게살두부, 송이버섯볶음의 클린한 맛이 거의 느껴지지 않았던 것.\n워낙 명성이 있는 곳이고 서비스 자체도 섬세한 곳이다보니 당연히 맛을 고려해 서빙 순서가 정해질 것이란, 너무 큰 기대를 갖고있었던 듯 하다.\n\n맛으로는 흑초탕수육은 생각보다 지방의 비율이 많아서 아주 강렬한 새콤함에도 불구하고 물려서 끝까지 먹지 못해 기대 대비 아쉬웠다.\n게살두부와 송이버섯볶음은 매우 부드럽고 따뜻해 소화가 어려운 어르신이나 아이가 먹기에도 안성맞춤일 것 같다. 관자볶음밥도 맛있는 편.\n\n딤섬도 매우 맛있고, 서빙 순서의 문제가 없는 코스를 먹는다면 아마 매우 만족도가 높을 것으로 예상된다.\n허나 가격대가 어느 정도 있는만큼 단품 요리 주문에 대한 세심한 고려도 함께 이뤄진다면 이곳의 요리에 대한 만족도도 더욱 높아지고 명성이 더욱 빛나지 않을까 하는 아쉬움이 드는 시간이었다."\n"21년 최신!!서울 내 애견 동반 식당 42곳 추천해 드립니다!!\n네이버 평점 기준 맛집만을 선정하였으며, 대형견 정보까지 모두 전해드립니다!\nhttps://smartstore.naver.com/ebookstorage/products/5672171999"\t호텔식당에 반려견 동반이 가능하다니 정말 감사할따름입니다~심지어 동반 가능한 좌석이 있는 공간이 꽤 넓게 따로 마련되어 있고 포토존,유모차도 있어요~음식 맛이야 보장이고 너무 기분좋게 먹고 왔습니다#반려견이랑\t"어쩌다 보니 팔레드신을 10일만에 재방문했습니다.\n\n전에 매번 알라까르트로 식사를 했는데 오늘은 룸에서 식사를 해서 세트를 처음으로 시켰네요. 참고로 여기는 얌차세트가 있고 스페셜코스가 있는데 얌차세트는 딤섬을 6개 선택할 수 있고 요리가 하나이고 코스는 정해진 딤섬이 3개 포함되고 요리가 3가지 포함입니다.\n\n저는 팔레드신 딤섬을 좋아하기 때문에 얌차세트를 선택하고 소룡포, 산라소룡포, 트러플 샤오마이, 하가우, 캐비어 해물 딤섬, 크리스피 챠슈빠우를 주문했습니다. 캐비어 해물 딤섬은 처음 먹'

# %%
# OKT 클래스를 이용한 명사확인 Okt (11초 : 4286), Kkma (37초 : 5572)
from konlpy.tag import Okt ### Okt를 활용하여 명사를 가져옴
t = Okt()

doc_nouns = t.nouns(doc_ko)
print( len( doc_nouns ) )
# Out:
# 45386

# %%
# nltk.Text()를 이용하여 nltk가 가지는 많은 기능을 사용 가능해짐.
ko = nltk.Text(doc_nouns, name="중식리뷰") # nltk는 영어 자연어 처리, 띄어쓰기 단위를 token이라고 함 
print(type(ko))
print(len(ko.tokens))   #그냥 해봄
# Out:
# <class 'nltk.text.Text'>
# 45386

# %%
### 단어들의 사용 횟수 확인 - 빈도 분석
type( ko.vocab() ), ko.vocab().most_common(50)
# Out:
# (nltk.probability.FreqDist,
#  [('맛', 1096),
#   ('것', 517),
#   ('만두', 403),
#   ('곳', 396),
#   ('메뉴', 352),
#   ('더', 342),
#   ('짬뽕', 324),
#   ('소스', 320),
#   ('방문', 303),
#   ('수', 281),
#   ('새우', 267),
#   ('탕수육', 258),
#   ('음식', 256),
#   ('때', 253),
#   ('집', 253),
#   ('주문', 253),
#   ('꼬치', 250),
#   ('느낌', 248),
#   ('정도', 247),
#   ('생각', 235),
#   ('요리', 234),
#   ('정말', 230),
#   ('이', 220),
#   ('좀', 212),
#   ('국물', 211),
#   ('탕', 210),
#   ('다른', 210),
#   ('고기', 206),
#   ('가격', 201),
#   ('튀김', 199),
#   ('가지', 193),
#   ('볶음밥', 191),
#   ('중식', 181),
#   ('향', 178),
#   ('밥', 173),
#   ('식사', 168),
#   ('안', 167),
#   ('조금', 167),
#   ('리뷰', 166),
#   ('하나', 166),
#   ('그', 164),
#   ('진짜', 163),
#   ('추천', 161),
#   ('면', 160),
#   ('딤섬', 158),
#   ('여기', 155),
#   ('처음', 154),
#   ('짜장면', 151),
#   ('맛집', 139),
#   ('중국', 138)])

# %%
### 한글에서는 따로 불용어 사전 라이브러리 없어, 따로 만들거나 또는 파일로 부터 불러올 수 있다.
stop_words = ['때','집','방문','것','만두','생각','여기', '그', '좀', '내','고기','갈비','방문',
'하나', '조금', '식사', '다음', '말','재','김밥','테이블','탕수육','주문',
'점', '또', '음식', '때', '정도','것','곳','수','짬뽕','더','더소스',
'다른', '생각', '이', '안', '진짜','냉면','정말','메뉴','리뷰부족','여기','진짜','리뷰','안']
new_ko = [ ]   #여기서 부터가 한글의 경우에 추가되는 부분
for one_word in ko:
  if one_word not in stop_words:  # 만약 one_word가 stop_word에 없으면 new_ko에 더하겠다. 
   new_ko.append(one_word)

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
new_ro2 = nltk.Text(new_ko, name="싸울아비 룬")
plt.figure(figsize=(20,16))
new_ro2.plot(50)

# %%
# Generate a word cloud image
jungsik_mask = np.array(Image.open("knife.jpg"))




# hansik_mask = np.array(Image.open("ddokbargi.jpg"))

# %%
data = new_ro2.vocab().most_common(1000)

# %%
## 워드 클라우드 표현을 위한 데이터 생성
## 약간의 시간이 필요.
wc = WordCloud(background_color='white', 
max_words=200,
mask=jungsik_mask,  #외곽형태 
contour_width=5, #외곽선
contour_color="steelblue",  # 색
font_path=path).generate_from_frequencies(dict(data))



plt.figure(figsize=(15,8)) # 크기
plt.imshow(wc, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()
